# %% [markdown]
# # 🎓 Student Performance Analysis | OutriX Internship - Data Science
#
# This project is part of my Data Science Internship at OutriX.
# Using Python, Pandas, Matplotlib, and Seaborn, I performed Exploratory Data Analysis (EDA) on a student academic performance dataset.
#
# 🔍 Objective: Identify key factors affecting student grades
# 📊 Steps:
# - Cleaned the dataset
# - Handled missing values
# - Explored correlations (e.g., study hours vs. exam score)
# - Visualized data with histograms, scatter plots, and heatmaps
#
# 📌 Tools Used: Python, Pandas, Matplotlib, Seaborn

# %%
import seaborn as sns

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Loading dataset

# %%
df = pd.read_csv("StudentPerformanceFactors.csv")

# %% [markdown]
# #### Checking for null values

# %%
df.isnull().sum()
# Out:
# Hours_Studied                  0
# Attendance                     0
# Parental_Involvement           0
# Access_to_Resources            0
# Extracurricular_Activities     0
# Sleep_Hours                    0
# Previous_Scores                0
# Motivation_Level               0
# Internet_Access                0
# Tutoring_Sessions              0
# Family_Income                  0
# Teacher_Quality               78
# School_Type                    0
# Peer_Influence                 0
# Physical_Activity              0
# Learning_Disabilities          0
# Parental_Education_Level      90
# Distance_from_Home            67
# Gender                         0
# Exam_Score                     0
# dtype: int64

# %%
df.describe()
# Out:
#        Hours_Studied   Attendance  Sleep_Hours  Previous_Scores  \
# count    6607.000000  6607.000000   6607.00000      6607.000000
# mean       19.975329    79.977448      7.02906        75.070531
# std         5.990594    11.547475      1.46812        14.399784
# min         1.000000    60.000000      4.00000        50.000000
# 25%        16.000000    70.000000      6.00000        63.000000
# 50%        20.000000    80.000000      7.00000        75.000000
# 75%        24.000000    90.000000      8.00000        88.000000
# max        44.000000   100.000000     10.00000       100.000000
#
#        Tutoring_Sessions  Physical_Activity   Exam_Score
# count        6607.000000        6607.000000  6607.000000
# mean            1.493719           2.967610    67.235659
# std             1.230570           1.031231     3.890456
# min             0.000000           0.000000    55.000000
# 25%             1.000000           2.000000    65.000000
# ...

# %% [markdown]
# #### Distribution of Exam Score

# %%
sns.histplot(df['Exam_Score'], kde=True)
# Out:
# <Axes: xlabel='Exam_Score', ylabel='Count'>

# %% [markdown]
# #### Correlation between Hours studied and Exam score

# %%
plt.scatter(df['Hours_Studied'], df['Exam_Score'], alpha = 0.5)
plt.xlabel("Hours Studied")
plt.ylabel("Exam Scores")
plt.title("Hours studied vs Exam Score")
# Out:
# Text(0.5, 1.0, 'Hours studied vs Exam Score')

# %% [markdown]
# #### Correlation between Attendance and Exam score

# %%
plt.scatter(df['Attendance'], df['Exam_Score'], alpha = 0.5)
plt.xlabel("Attendance")
plt.ylabel("Exam Scores")
plt.title("Attendance vs Exam Score")
# Out:
# Text(0.5, 1.0, 'Attendance vs Exam Score')

# %% [markdown]
# ### Barplot of studied hours and exam score
# - It clearly shows that study hours is directly proportional to Exam Scores

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming df is your DataFrame
# Bin Hours_Studied into intervals of 5
df['Study_Bin'] = pd.cut(df['Hours_Studied'], bins=range(0, df['Hours_Studied'].max()+5, 5))

# Plot average Exam_Score by Study_Bin
plt.figure(figsize=(10, 6))
sns.barplot(data=df, x='Study_Bin', y='Exam_Score', estimator='mean')
plt.xticks(rotation=45)
plt.title('Average Exam Score by Hours Studied Interval')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Imputing the missing values

# %%
df['Teacher_Quality'] = df['Teacher_Quality'].fillna(df['Teacher_Quality'].mode()[0])

# %%
df['Parental_Education_Level'] = df['Parental_Education_Level'].fillna(df['Parental_Education_Level'].mode()[0])

# %%
df['Distance_from_Home']= df['Distance_from_Home'].fillna(df['Distance_from_Home'].mode()[0])

# %% [markdown]
# # Understanding Distribution

# %%
sns.histplot(df['Hours_Studied'], kde=True)
plt.title("Distribution of Hours_Studied")
# Out:
# Text(0.5, 1.0, 'Distribution of Hours_Studied')

# %%
sns.histplot(df['Attendance'], kde=True)
plt.title("Distribution of Attendance")
# Out:
# Text(0.5, 1.0, 'Distribution of Attendance')

# %%
sns.histplot(df['Previous_Scores'], kde=True)
plt.title("Distribution of Previous_Scores")
# Out:
# Text(0.5, 1.0, 'Distribution of Previous_Scores')

# %%
sns.histplot(df['Sleep_Hours'], kde=True)
plt.title("Distribution of Sleep_Hours")
# Out:
# Text(0.5, 1.0, 'Distribution of Sleep_Hours')

# %%
df[['Hours_Studied', 'Attendance', 'Previous_Scores']].describe()
# Out:
#        Hours_Studied   Attendance  Previous_Scores
# count    6607.000000  6607.000000      6607.000000
# mean       19.975329    79.977448        75.070531
# std         5.990594    11.547475        14.399784
# min         1.000000    60.000000        50.000000
# 25%        16.000000    70.000000        63.000000
# 50%        20.000000    80.000000        75.000000
# 75%        24.000000    90.000000        88.000000
# max        44.000000   100.000000       100.000000

# %% [markdown]
# ## For categorical values

# %%
sns.boxplot(x ='Parental_Involvement', y='Exam_Score', data=df)
plt.title("Parental Involvement vs Exam scores")
# Out:
# Text(0.5, 1.0, 'Parental Involvement vs Exam scores')

# %%
sns.boxplot(x ='Motivation_Level', y='Exam_Score', data=df)
plt.title("Motivation_Level vs Exam scores")
plt.grid(True)

# %%
sns.boxplot(x ='Internet_Access', y='Exam_Score', data=df)
plt.title("Internet_Access vs Exam scores")
plt.grid(True)

# %%
sns.boxplot(x ='Teacher_Quality', y='Exam_Score', data=df)
plt.title("Teacher_Quality vs Exam scores")
plt.grid(True)

# %%
sns.boxplot(x ='Peer_Influence', y='Exam_Score', data=df)
plt.title("Peer_Influence vs Exam scores")
plt.grid(True)

# %%
sns.boxplot(x ='Gender', y='Exam_Score', data=df)
plt.title("Gender vs Exam scores")
plt.grid(True)

# %% [markdown]
# ### From these categorical graph, the insights that come into light:
# - Students with **High Motivation Level** have noticeably higher exam scores. This suggests motivation is a strong predictor of performance.
# - Students with **Internet Connection** have higher exam score than Students without internet connection.
# - Students who have **Good Peer Influence** have noticable higher exam score.

# %% [markdown]
# ### Heatmap for all numerical values

# %%
plt.figure(figsize=(10,6))
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap='coolwarm')
plt.title("Correlation between numeric features")
# Out:
# Text(0.5, 1.0, 'Correlation between numeric features')

# %% [markdown]
# ### Key insights from Heatmap:
# - it is clear that **Attendance** is most **Most positively Correlated**. Students with higher attendance tends to score better in exams.
# - **study hours** is next to attendance, study hours is also strongly Correlated - Studying more improve performance.

# %% [markdown]
# ### Correlation of study hours, attendance, previous score And Exam score

# %%
sns.pairplot(df[['Hours_Studied', 'Attendance', 'Previous_Scores', 'Exam_Score']])

# %% [markdown]
# ## 🔍 Summary of Findings
#
# After performing Exploratory Data Analysis (EDA) on the student performance dataset, several important patterns and relationships emerged:
#
# ### 📊 Key Numeric Insights:
# - **Attendance** shows the strongest positive correlation with exam performance (**r = 0.58**). Students with higher attendance tend to score significantly better, emphasizing the importance of classroom presence.
# - **Hours Studied** also strongly impacts performance (**r = 0.45**), confirming that consistent study habits contribute meaningfully to academic success.
# - **Previous Scores** and **Tutoring Sessions** have a moderate positive effect, suggesting that both prior knowledge and academic support play important roles.
# - **Sleep Hours** and **Physical Activity**, while important for health, show very weak or no direct correlation with final exam scores in this dataset.
#
# ### 📊 Key Categorical Insights:
# - Students with **High Motivation Levels** consistently outperform their peers. Motivation appears to be a key psychological driver of success.
# - Those with **Internet Access** tend to score higher, likely due to easier access to learning materials and online resources.
# - A **Positive Peer Influence** is associated with better performance, suggesting the academic value of supportive social circles.
# - **Parental Involvement** and **Teacher Quality** also show upward trends with Exam Scores, although with less pronounced effects.
#
# ### 📌 Overall Conclusion:
# Multiple interconnected factors contribute to student performance. Academic habits (like studying and attending class), motivational and environmental support (peer influence, internet, and parental involvement), and institutional support (tutoring, teaching quality) all play measurable roles.
#
# Understanding these insights can help educators, parents, and students focus on the most impactful areas to drive improvement in academic outcomes.
